# %% [markdown]
# # Exercício 1
# Crie um programa que mostre "Olá, Mundo!" na tela.<br>
# Curso em Vídeo | [Desafio e resolução](https://youtu.be/nIHq1MtJaKs?si=g9ontXQrdUyBtktJ)

# %%
print ("Olá, Mundo!")
