# %% [markdown]
# # Exercício 2
# Crie um programa que leia o nome de um usuário e diga "É um prazer te conhecer, @Usuário".<br>
# Curso em Vídeo | [Desafio e resolução](https://youtu.be/FNqdV5Zb_5Q?si=vfeRvE6CqeNGLqDg)

# %%
nome = input("Digite seu nome: ")
print(f"É um prazer te conhecer, {nome}!")
