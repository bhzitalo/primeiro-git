# %% [markdown]
# # Exercício 3
# Crie um programa que leia dois números e mostre a soma entre eles.<br>
# Curso em Vídeo | [Desafio e resolução](https://youtu.be/PB254Cfjlyk?si=_uC1uePO757IrHQK)

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))
soma = num1 + num2
print(f"A soma de {num1} + {num2} é igual a {soma}")

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))
print(f" A soma de {num1} + {num2} é igual a {num1 + num2}")
