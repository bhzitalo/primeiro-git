# %% [markdown]
# # Passo a Passo do Desafio
# 1. Entrar no sistema da empresa
# 2. Navegar no sistema e encontrar a base de dados
# 3. Exportar a base de dados
# 4. Calcular os indicadores (farutamento e quantidade de produtos vendidos)
# 5. Enviar as informações por e-mail

# %%
import pyautogui
import time

# Passo 1: abrir o navegador e entrar no sistema da empresa
pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")
time.sleep(1) # Espera 1 segundos

pyautogui.write("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga")
pyautogui.press("enter")
